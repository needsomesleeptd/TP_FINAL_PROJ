# %%
import pandas as pd

# %%
df = pd.read_csv("dist.csv")

# %%
df
# Out:
#          id                                           title  \
# 0     32426       развлекательно-игровой центр SТАНЦИЯ 2025
# 1     34245  клуб виртуальной реальности «Нереальное место»
# 2     33485                                    «Москвариум»
# 3     13356            комплекс водных развлечений «Мореон»
# 4       531                     Музей-заповедник «Царицыно»
# ...     ...                                             ...
# 1215  15168                           памятник собаке Лайке
# 1216   6082                                   Бар Law & Son
# 1217   5005                              Ресторан «Буйабес»
# 1218    533                                Памятник Доценту
# 1219   2739                            Караоке-клуб «Трели»
#
#                 short_title                               address location  \
# 0              SТАНЦИЯ 2025       пр-д Михайловский, д. 1, стр. 1      msk
# 1          Нереальное место  Нижний Сусальный пер., д. 5, стр. 5А      msk
# 2              «Москвариум»          просп. Мира, д. 119, стр. 23      msk
# 3                    Мореон                ул. Голубинская, д. 16      msk
# 4                  Царицыно                    ул. Дольская, д. 1      msk
# ...                     ...                                   ...      ...
# 1215  Памятник собаке Лайке    Петровско-Разумовская аллея, д.12а      msk
# 1216              Law & Son         ул. Садовая-Каретная, д. 24/7      msk
# 1217                Буйабес               просп. Ленинский, д. 37      msk
# 1218       памятник Доценту              ул. Мосфильмовская, д. 8      msk
# 1219                  Трели   просп. Ленинградский, д. 47, стр. 2      msk
#
#                                               timetable  \
# 0                 пн–пт 13:00–22:00, сб, вс 11:00–22:00
# 1                   пн–пт 12:00–0:00, сб, вс 10:00–0:00
# 2                                 ежедневно 10:00–22:00
# 3                   пн–пт 9:00–22:00, сб, вс 9:00–22:00
# 4     вт–чт 10:00–18:00, пт, сб 10:00–20:00, вс 10:0...
# ...                                                 ...
# 1215                                                NaN
# 1216  пн–чт 13:00–1:00, пт 13:00–6:00, сб 14:00–6:00...
# 1217                               ежедневно 11:30–0:00
# 1218                                ежедневно весь день
# 1219                               ежедневно 17:00–6:00
#
#                                    phone  \
# 0                       +7 495 215-56-31
# 1                       +7 495 121-33-62
# 2                       +7 499 677-77-77
# 3                       +7 495 481-60-43
# 4                       +7 495 322-44-33
# ...                                  ...
# 1215                                 NaN
# 1216                    +7 495 649-01-89
# 1217                                 NaN
# 1218                                 NaN
# 1219  +7 499 157-52-21, +7 968 368-03-03
#
#                                                  images  \
# 0     [{'image': 'https://media.kudago.com/images/pl...
# 1     [{'image': 'https://media.kudago.com/images/pl...
# 2     [{'image': 'https://media.kudago.com/images/pl...
# 3     [{'image': 'https://media.kudago.com/images/pl...
# 4     [{'image': 'https://media.kudago.com/images/pl...
# ...                                                 ...
# 1215  [{'image': 'https://media.kudago.com/images/pl...
# 1216  [{'image': 'https://media.kudago.com/images/pl...
# 1217  [{'image': 'https://media.kudago.com/images/pl...
# 1218  [{'image': 'https://media.kudago.com/images/pl...
# 1219  [{'image': 'https://media.kudago.com/images/pl...
#
#                                             description  \
# 0     SТАНЦИЯ 2025 — необычный развлекательно-игрово...
# 1     Десятки VR-игр всех жанров для всех возрастов,...
# 2     В «Москвариуме» на ВДНХ можно интересно провес...
# 3     Крупнейший в Восточной Европе комплекс водных ...
# 4     Царские дворцы в стиле русской готики, чистые ...
# ...                                                 ...
# 1215  Неподалёку от Института военной медицины стоит...
# 1216  Law & Son — это кусочек Лондона или Эдинбурга ...
# 1217  «Буйабес» на Ленинском проспекте — место, куда...
# 1218  На аллее звёзд киностудии «Мосфильм» в 2001 го...
# 1219  Ещё одна возможность культурно отдохнуть за уж...
#
#                                               body_text  \
# 0     Как вам идея провести детский день рождения, т...
# 1     Согласно Tripadvisor, с 2016 года клуб не поки...
# 2     «Москвариум» — это частичка океана в центре Мо...
# 3     Ритм современной жизни заставляет жителей и го...
# 4     В XVIII веке по указу императрицы Екатерины II...
# ...                                                 ...
# 1215  Этот памятник выполнен из бронзы в виде большо...
# 1216  Бар Дмитрия Соколова Law & Son знакомит посети...
# 1217  Ресторан «Буйабес» отличается элегантным интер...
# 1218  Впрочем, если быть точнее, то это вовсе не пре...
# 1219  Караоке-клуб «Трели» предоставляет возможность...
#
#                                             foreign_url  \
# 0                         https://vk.com/spirit.station
# 1                        https://www.nerealnoemesto.ru/
# 2                        https://tickets.moskvarium.ru/
# 3     http://more-on.ru/?utm_source=kudago&utm_mediu...
# 4                       http://www.tsaritsyno-museum.ru
# ...                                                 ...
# 1215                                                NaN
# 1216                                                NaN
# 1217                                                NaN
# 1218                                                NaN
# 1219                               https://vk.com/treli
#
#                                      subway  \
# 0                    Волгоградский проспект
# 1                                       NaN
# 2                    Ботанический сад, ВДНХ
# 3                                   Ясенево
# 4                         Орехово, Царицыно
# ...                                     ...
# 1215                                 Динамо
# 1216            Маяковская, Цветной бульвар
# 1217                     Ленинский проспект
# 1218  Кутузовская, Спортивная, Студенческая
# 1219                               Аэропорт
#
#                                                  coords  favorites_count  \
# 0     {'lat': 55.73190099999975, 'lon': 37.686732899...              167
# 1     {'lat': 55.75981199999999, 'lon': 37.664224999...              102
# 2     {'lat': 55.83273199999982, 'lon': 37.618315999...              144
# 3     {'lat': 55.59724599999998, 'lon': 37.527184000...              453
# 4     {'lat': 55.61662499999999, 'lon': 37.683930999...             1170
# ...                                                 ...              ...
# 1215       {'lat': 55.79423399999997, 'lon': 37.559766}               15
# 1216  {'lat': 55.77297278148041, 'lon': 37.611415447...               53
# 1217                 {'lat': 55.709865, 'lon': 37.5865}               10
# 1218  {'lat': 55.72298899999996, 'lon': 37.527013000...               51
# 1219  {'lat': 55.79881889999995, 'lon': 37.532361500...                4
#
#       comments_count  is_closed  \
# 0                  0      False
# 1                 15      False
# 2                  2      False
# 3                 27      False
# 4                  7      False
# ...              ...        ...
# 1215               0      False
# 1216              44      False
# 1217               0      False
# 1218               1      False
# 1219               1      False
#
#                                                    tags  \
# 0     ['клубы виртуальной реальности', 'парки аттрак...
# 1     ['с друзьями', 'виртуальная реальность', 'лучш...
# 2     ['детские развлекательные центры', 'всей семьё...
# 3     ['всей семьёй', 'аквапарки', 'детям', 'развлеч...
# 4     ['парки (интересные места, отдых)', 'зимний от...
# ...                                                 ...
# 1215  ['достопримечательности', 'космос', 'день косм...
# 1216  ['еда', 'рестораны и кафе', '18+', 'про еду', ...
# 1217  ['отдельные кабинки', 'wi-fi', 'алкоголь', 'ры...
# 1218  ['город', 'достопримечательности', 'интересные...
# 1219  ['караоке', 'отдельные кабинки', 'wi-fi', 'алк...
#
#                                              categories
# 0                   ['amusement', 'kids', 'recreation']
# 1                       ['amusement', 'kids', 'sights']
# 2                       ['amusement', 'kids', 'sights']
# 3                   ['amusement', 'kids', 'recreation']
# 4     ['kids', 'museums', 'park', 'palace', 'attract...
# ...                                                 ...
# 1215                                    ['attractions']
# 1216                             ['restaurants', 'bar']
# 1217                                    ['restaurants']
# 1218                          ['attractions', 'sights']
# 1219                                          ['clubs']
#
# [1220 rows x 18 columns]

# %%
df["title"][0]
# Out:
# 'развлекательно-игровой центр SТАНЦИЯ 2025'

# %%
new_df = df[["title", "images"]]

# %%
import json

# %%
new_df["images"] = new_df["images"].apply(lambda row: json.loads(row.replace("'", '"'))[0]["image"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19872\1090405286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["images"] = new_df["images"].apply(lambda row: json.loads(row.replace("'", '"'))[0]["image"])

# %%
new_df.to_csv("dist_for_pg.csv", index=False)
